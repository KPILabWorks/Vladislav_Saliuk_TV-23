# %%
import pandas as pd 
df = pd.read_csv("house_sales.csv")
df
# Out:
#       DocumentDate  SalePrice  PropertyID   PropertyType          ym  zhvi_px  \
# 0       2014-09-16     280000     1000102      Multiplex  2014-09-01   405100
# 1       2006-06-16    1000000     1200013  Single Family  2006-06-01   404400
# 2       2007-01-29     745000     1200019  Single Family  2007-01-01   425600
# 3       2008-02-25     425000     2800016  Single Family  2008-02-01   418400
# 4       2013-03-29     240000     2800024  Single Family  2013-03-01   351600
# ...            ...        ...         ...            ...         ...      ...
# 22682   2011-04-08     325000  9842300710  Single Family  2011-04-01   318700
# 22683   2007-09-28    1580000  9845500010  Single Family  2007-09-01   433500
# 22684   2012-07-09     165000  9899200010  Single Family  2012-07-01   325300
# 22685   2006-05-26     315000  9900000355  Single Family  2006-05-01   400600
# 22686   2007-01-09     465000  9906000035  Single Family  2007-01-01   425600
#
# ...

# %%
df.head()
# Out:
#   DocumentDate  SalePrice  PropertyID   PropertyType          ym  zhvi_px  \
# 0   2014-09-16     280000     1000102      Multiplex  2014-09-01   405100
# 1   2006-06-16    1000000     1200013  Single Family  2006-06-01   404400
# 2   2007-01-29     745000     1200019  Single Family  2007-01-01   425600
# 3   2008-02-25     425000     2800016  Single Family  2008-02-01   418400
# 4   2013-03-29     240000     2800024  Single Family  2013-03-01   351600
#
#    zhvi_idx  AdjSalePrice  NbrLivingUnits  SqFtLot  ...  Bathrooms  Bedrooms  \
# 0  0.930836      300805.0               2     9373  ...       3.00         6
# 1  0.929228     1076162.0               1    20156  ...       3.75         4
# 2  0.977941      761805.0               1    26036  ...       1.75         4
# 3  0.961397      442065.0               1     8618  ...       3.75         5
# 4  0.807904      297065.0               1     8620  ...       1.75         4
#
# ...

# %%
df.tail()
# Out:
#       DocumentDate  SalePrice  PropertyID   PropertyType          ym  zhvi_px  \
# 22682   2011-04-08     325000  9842300710  Single Family  2011-04-01   318700
# 22683   2007-09-28    1580000  9845500010  Single Family  2007-09-01   433500
# 22684   2012-07-09     165000  9899200010  Single Family  2012-07-01   325300
# 22685   2006-05-26     315000  9900000355  Single Family  2006-05-01   400600
# 22686   2007-01-09     465000  9906000035  Single Family  2007-01-01   425600
#
#        zhvi_idx  AdjSalePrice  NbrLivingUnits  SqFtLot  ...  Bathrooms  \
# 22682  0.732307      443803.0               1     5468  ...       1.75
# 22683  0.996094     1586196.0               1    23914  ...       4.50
# 22684  0.747472      220744.0               1    11170  ...       1.00
# 22685  0.920496      342207.0               1     6223  ...       2.00
# 22686  0.977941      475489.0               1     4400  ...       1.50
#
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22682    False
# 22683    False
# 22684    False
# 22685    False
# 22686    False
# Length: 22687, dtype: bool

# %%
print(df.dtypes)
# Out:
# DocumentDate        object
# SalePrice            int64
# PropertyID           int64
# PropertyType        object
# ym                  object
# zhvi_px              int64
# zhvi_idx           float64
# AdjSalePrice       float64
# NbrLivingUnits       int64
# SqFtLot              int64
# SqFtTotLiving        int64
# SqFtFinBasement      int64
# Bathrooms          float64
# Bedrooms             int64
# BldgGrade            int64
# YrBuilt              int64
# YrRenovated          int64
# TrafficNoise         int64
# LandVal              int64
# ImpsVal              int64
# ZipCode              int64
# NewConstruction       bool
# dtype: object

# %%
df.groupby("PropertyType").count()
# Out:
#                DocumentDate  SalePrice  PropertyID     ym  zhvi_px  zhvi_idx  \
# PropertyType
# Multiplex               257        257         257    257      257       257
# Single Family         20720      20720       20720  20720    20720     20720
# Townhouse              1710       1710        1710   1710     1710      1710
#
#                AdjSalePrice  NbrLivingUnits  SqFtLot  SqFtTotLiving  ...  \
# PropertyType                                                         ...
# Multiplex               257             257      257            257  ...
# Single Family         20720           20720    20720          20720  ...
# Townhouse              1710            1710     1710           1710  ...
#
#                Bathrooms  Bedrooms  BldgGrade  YrBuilt  YrRenovated  \
# PropertyType
# Multiplex            257       257        257      257          257
# Single Family      20720     20720      20720    20720        20720
# ...

# %%
df.groupby("PropertyType").min()
# Out:
#               DocumentDate  SalePrice  PropertyID          ym  zhvi_px  \
# PropertyType
# Multiplex       2006-01-03     120000     1000102  2006-01-01   311900
# Single Family   2006-01-03      10480     1200013  2006-01-01   311600
# Townhouse       2006-01-03       3000     3600090  2006-01-01   311600
#
#                zhvi_idx  AdjSalePrice  NbrLivingUnits  SqFtLot  SqFtTotLiving  \
# PropertyType
# Multiplex      0.716682      153872.0               1     1191            790
# Single Family  0.715993       11632.0               1      875            370
# Townhouse      0.715993        3368.0               1      494            560
#
#                ...  Bathrooms  Bedrooms  BldgGrade  YrBuilt  YrRenovated  \
# PropertyType   ...
# Multiplex      ...        1.0         2          5     1900            0
# Single Family  ...        0.0         0          3     1900            0
# Townhouse      ...        0.0         0          6     1900            0
#
# ...

# %%
df.groupby("PropertyType").max()
# Out:
#               DocumentDate  SalePrice  PropertyID          ym  zhvi_px  \
# PropertyType
# Multiplex       2015-04-28    1675000  9830200230  2015-04-01   434600
# Single Family   2015-05-29   11000000  9906000035  2015-05-01   435200
# Townhouse       2015-03-05    2060000  9834201476  2015-03-01   434600
#
#                zhvi_idx  AdjSalePrice  NbrLivingUnits  SqFtLot  SqFtTotLiving  \
# PropertyType
# Multiplex      0.998621     1807937.0               5   125017           5600
# Single Family  1.000000    11644855.0               4  1024068          10740
# Townhouse      0.998621     2086853.0               3     7218           4830
#
#                ...  Bathrooms  Bedrooms  BldgGrade  YrBuilt  YrRenovated  \
# PropertyType   ...
# Multiplex      ...       6.75        13         11     2012         2014
# Single Family  ...       8.00        33         13     2015         2016
# Townhouse      ...       5.75         9         11     2015         2011
#
# ...

# %%
df.groupby("PropertyType").agg({'SqFtLot':['min', 'max', 'count', 'sum'] , 'Bathrooms':['min', 'max', 'count', 'sum']})
# Out:
#               SqFtLot                            Bathrooms               \
#                   min      max  count        sum       min   max  count
# PropertyType
# Multiplex        1191   125017    257    1613664       1.0  6.75    257
# Single Family     875  1024068  20720  261781448       0.0  8.00  20720
# Townhouse         494     7218   1710    3093953       0.0  5.75   1710
#
#
#                     sum
# PropertyType
# Multiplex        664.50
# Single Family  44771.25
# Townhouse       3942.50

# %%
df.drop(['DocumentDate', 'ym'], axis=1)
df.groupby(['SalePrice', 'AdjSalePrice']).min()
# Out:
#                        DocumentDate  PropertyID   PropertyType          ym  \
# SalePrice AdjSalePrice
# 3000      3368.0         2006-02-01  7663700832      Townhouse  2006-02-01
# 10480     11632.0        2006-03-17  4024101940  Single Family  2006-03-01
# 22151     23980.0        2014-07-01  1591600507  Single Family  2014-07-01
# 50000     54373.0        2014-06-16  7893803775  Single Family  2014-06-01
# 50500     52984.0        2006-09-14  9320901080      Townhouse  2006-09-01
# ...                             ...         ...            ...         ...
# 6200000   6881510.0      2006-03-28  3358500470  Single Family  2006-03-01
# 6250000   7865818.0      2010-06-01  1954700280  Single Family  2010-06-01
# 6500000   6943544.0      2008-05-09  5627300100  Single Family  2008-05-01
# 7600000   8178833.0      2006-06-07  3625059036  Single Family  2006-06-01
# 11000000  11644855.0     2006-08-22  7397300120  Single Family  2006-08-01
#
# ...
